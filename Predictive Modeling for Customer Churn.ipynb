# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('bank.csv',delimiter = ';')

# %%
train_df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
train_df.sample(5)
# Out:
#       age            job   marital  education default  balance housing loan  \
# 1691   51    blue-collar  divorced    primary      no      -28      no  yes
# 856    49     technician   married  secondary     yes    -1680     yes  yes
# 2844   46         admin.   married  secondary      no      120     yes   no
# 3336   37  self-employed   married  secondary      no      215     yes   no
# 54     53    blue-collar   married  secondary      no     2231     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 1691   unknown    2   jul       220         2     -1         0  unknown  no
# 856    unknown   27   jun        92         4     -1         0  unknown  no
# 2844   unknown   14   may        20        11     -1         0  unknown  no
# 3336   unknown    6   jun        61         1     -1         0  unknown  no
# 54    cellular   14   jul       272         3     -1         0  unknown  no

# %%
train_df.shape
# Out:
# (4521, 17)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
train_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
train_df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
train_df.duplicated().sum()
# Out:
# 0

# %%
train_df.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
plt.figure(figsize=(20,10))

plt.subplot(3,3,1)
sns.countplot(x=train_df['job'])

plt.subplot(3,3,2)
sns.countplot(x=train_df['marital'])

plt.subplot(3,3,3)
sns.countplot(x=train_df['education'])

plt.subplot(3,3,4)
sns.countplot(x=train_df['default'])

plt.subplot(3,3,5)
sns.countplot(x=train_df['housing'])

plt.subplot(3,3,6)
sns.countplot(x=train_df['loan'])

plt.subplot(3,3,7)
sns.countplot(x=train_df['contact'])

plt.subplot(3,3,8)
sns.countplot(x=train_df['month'])

plt.subplot(3,3,9)
sns.countplot(x=train_df['poutcome'])

plt.show()

# %%
plt.figure(figsize=(20,10))

plt.subplot(3,3,1)
sns.countplot(x=train_df['job'],hue = train_df['y'])

plt.subplot(3,3,2)
sns.countplot(x=train_df['marital'],hue = train_df['y'])

plt.subplot(3,3,3)
sns.countplot(x=train_df['education'],hue = train_df['y'])

plt.subplot(3,3,4)
sns.countplot(x=train_df['default'],hue = train_df['y'])

plt.subplot(3,3,5)
sns.countplot(x=train_df['housing'],hue = train_df['y'])

plt.subplot(3,3,6)
sns.countplot(x=train_df['loan'],hue = train_df['y'])

plt.subplot(3,3,7)
sns.countplot(x=train_df['contact'],hue = train_df['y'])

plt.subplot(3,3,8)
sns.countplot(x=train_df['month'],hue = train_df['y'])

plt.subplot(3,3,9)
sns.countplot(x=train_df['previous'],hue = train_df['y'])

plt.show()

# %%
train_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
plt.subplot(3,3,1)
sns.histplot(x=train_df['age'])

plt.subplot(3,3,2)
sns.histplot(x=train_df['balance'])

plt.subplot(3,3,3)
sns.histplot(x=train_df['day'])

plt.subplot(3,3,4)
sns.histplot(x=train_df['campaign'])

plt.subplot(3,3,5)
sns.histplot(x=train_df['pdays'])

plt.subplot(3,3,6)
sns.histplot(x=train_df['previous'])
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(3,3,1)
sns.distplot(x=train_df['age'])

plt.subplot(3,3,2)
sns.distplot(x=train_df['balance'])

plt.subplot(3,3,3)
sns.distplot(x=train_df['day'])

plt.subplot(3,3,4)
sns.distplot(x=train_df['campaign'])

plt.subplot(3,3,5)
sns.distplot(x=train_df['pdays'])

plt.subplot(3,3,6)
sns.distplot(x=train_df['previous'])
plt.show()
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\abc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(20,10))
plt.subplot(3,3,1)
sns.boxplot(x=train_df['age'])

plt.subplot(3,3,2)
sns.boxplot(x=train_df['balance'])

plt.subplot(3,3,3)
sns.boxplot(x=train_df['day'])

plt.subplot(3,3,4)
sns.boxplot(x=train_df['campaign'])

plt.subplot(3,3,5)
sns.boxplot(x=train_df['pdays'])

plt.subplot(3,3,6)
sns.boxplot(x=train_df['previous'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("account balance less than 0 customers")
sns.countplot(x=train_df[train_df['balance'] < 0 ]['y'])

plt.subplot(1,2,2)
plt.title("account balance grether than 0 customers")
sns.countplot(x=train_df[train_df['balance'] > 0 ]['y'])

plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=train_df['day'],hue=train_df['y'])
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x=train_df['education'],hue = train_df['y'])
plt.show()

# %%
train_df[train_df['y'] == 'yes']
# Out:
#       age            job   marital  education default  balance housing loan  \
# 13     20        student    single  secondary      no      502      no   no
# 30     68        retired  divorced  secondary      no     4189      no   no
# 33     32     management    single   tertiary      no     2536     yes   no
# 34     49     technician   married   tertiary      no     1235      no   no
# 36     78        retired  divorced    primary      no      229      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4494   26     technician    single  secondary      no      668     yes   no
# 4503   60  self-employed   married    primary      no      362      no  yes
# 4504   42    blue-collar    single  secondary      no     1080     yes  yes
# 4505   32         admin.    single  secondary      no      620     yes   no
# 4511   46    blue-collar   married  secondary      no      668     yes   no
#
# ...

# %%
sns.pairplot(train_df[train_df['y'] == 'yes'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

train_df['y'] = le.fit_transform(train_df['y'])

# %%
train_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# decision tree
# random forest
# svm
# logistic regression
# knn
# gradient boosting

# %%
x = train_df.iloc[:,:-1]
y = train_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler


transformer = ColumnTransformer([
     ('traf1',OneHotEncoder(), ['job','marital','default', 'housing', 'loan', 'contact','month','poutcome']),
    ('traf2',OrdinalEncoder(categories=[['unknown', 'primary','secondary', 'tertiary']],dtype=np.int32), ['education']),
    ('traf3', StandardScaler(),['age','balance','day','duration','campaign','pdays','previous'])
],remainder='passthrough')

# %%
x_train_traf = transformer.fit_transform(x_train)
x_test_traf = transformer.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score, roc_auc_score

dt = DecisionTreeClassifier(max_depth=100,random_state=2)

dt.fit(x_train_traf,y_train)

ypred = dt.predict(x_test_traf)

print('Decision Tree Classifier')
print('accuracy_score: ',accuracy_score(y_test,ypred))
print('precision_score: ',precision_score(y_test,ypred))
print('recall_score: ',recall_score(y_test,ypred))
print('f1_score: ',f1_score(y_test,ypred))
print('roc auc score: ',roc_auc_score(y_test,ypred))
# Out:
# Decision Tree Classifier
# accuracy_score:  0.8828729281767956
# precision_score:  0.42718446601941745
# recall_score:  0.4835164835164835
# f1_score:  0.4536082474226804
# roc auc score:  0.7055174555174556

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000,random_state=2)

lr.fit(x_train_traf,y_train)

ypred1 = lr.predict(x_test_traf)

print('Logistic Regression')
print('accuracy_score: ',accuracy_score(y_test,ypred1))
print('precision_score: ',precision_score(y_test,ypred1))
print('recall_score: ',recall_score(y_test,ypred1))
print('f1_score: ',f1_score(y_test,ypred1))
print('roc auc score: ',roc_auc_score(y_test,ypred1))
# Out:
# Logistic Regression
# accuracy_score:  0.912707182320442
# precision_score:  0.6578947368421053
# recall_score:  0.27472527472527475
# f1_score:  0.3875968992248062
# roc auc score:  0.6293773793773793

# %%
from sklearn.svm import SVC

svm = SVC(random_state=2,kernel='poly',degree=5)

svm.fit(x_train_traf,y_train)

ypred2 = svm.predict(x_test_traf)

print('Support Vector Classifier')
print('accuracy_score: ',accuracy_score(y_test,ypred2))
print('precision_score: ',precision_score(y_test,ypred2))
print('recall_score: ',recall_score(y_test,ypred2))
print('f1_score: ',f1_score(y_test,ypred2))
print('roc auc score: ',roc_auc_score(y_test,ypred2))
# Out:
# Support Vector Classifier
# accuracy_score:  0.912707182320442
# precision_score:  0.6428571428571429
# recall_score:  0.2967032967032967
# f1_score:  0.40601503759398505
# roc auc score:  0.6391378891378892

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=2)

knn.fit(x_train_traf,y_train)

ypred3 = knn.predict(x_test_traf)

print('K Neighbors Classifier')
print('accuracy_score: ',accuracy_score(y_test,ypred3))
print('precision_score: ',precision_score(y_test,ypred3))
print('recall_score: ',recall_score(y_test,ypred3))
print('f1_score: ',f1_score(y_test,ypred3))
print('roc auc score: ',roc_auc_score(y_test,ypred3))
# Out:
# K Neighbors Classifier
# accuracy_score:  0.8983425414364641
# precision_score:  0.48
# recall_score:  0.13186813186813187
# f1_score:  0.20689655172413796
# roc auc score:  0.557948807948808

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=2)

rf.fit(x_train_traf,y_train)

ypred4 = rf.predict(x_test_traf)

print('Random Forest Classifier')
print('accuracy_score: ',accuracy_score(y_test,ypred4))
print('precision_score: ',precision_score(y_test,ypred4))
print('recall_score: ',recall_score(y_test,ypred4))
print('f1_score: ',f1_score(y_test,ypred4))
print('roc auc score: ',roc_auc_score(y_test,ypred4))
# Out:
# Random Forest Classifier
# accuracy_score:  0.9104972375690608
# precision_score:  0.6190476190476191
# recall_score:  0.2857142857142857
# f1_score:  0.39097744360902253
# roc auc score:  0.633029133029133

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(learning_rate=0.1,max_depth=3,n_estimators=500,random_state=2)

gb.fit(x_train_traf,y_train)

ypred5 = gb.predict(x_test_traf)

print('Gradient Boosting Classifier')
print('accuracy_score: ',accuracy_score(y_test,ypred5))
print('precision_score: ',precision_score(y_test,ypred5))
print('recall_score: ',recall_score(y_test,ypred5))
print('f1_score: ',f1_score(y_test,ypred5))
print('roc auc score: ',roc_auc_score(y_test,ypred5))
# Out:
# Gradient Boosting Classifier
# accuracy_score:  0.9160220994475138
# precision_score:  0.6
# recall_score:  0.4945054945054945
# f1_score:  0.5421686746987951
# roc auc score:  0.7288252288252288
